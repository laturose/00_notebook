# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ####  http://www.ritchieng.com/pandas-sorting/
# https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %% [markdown]
# # how to read csv
#
# pandas.read_table(filepath_or_buffer, sep='\t', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, skip_footer=0, doublequote=True, delim_whitespace=False, as_recarray=None, compact_ints=None, use_unsigned=None, low_memory=True, buffer_lines=None, memory_map=False, float_precision=None)[source]
#
#
# 读取CSV（逗号分割）文件到DataFrame
# 也支持文件的部分导入和选择迭代
# 更多帮助参见：http://pandas.pydata.org/pandas-docs/stable/io.html
# 参数：
# filepath_or_buffer : str，pathlib。str, pathlib.Path, py._path.local.LocalPath or any object with a read() method (such as a file handle or StringIO)
# 可以是URL，可用URL类型包括：http, ftp, s3和文件。对于多文件正在准备中
# 本地文件读取实例：://localhost/path/to/table.csv
#
# sep : str, default ‘,’
# 指定分隔符。如果不指定参数，则会尝试使用逗号分隔。分隔符长于一个字符并且不是‘\s+’,将使用python的语法分析器。并且忽略数据中的逗号。正则表达式例子：'\r\t'
#
# delimiter : str, default None
# 定界符，备选分隔符（如果指定该参数，则sep参数失效）
#
# delim_whitespace : boolean, default False.
# 指定空格(例如’ ‘或者’ ‘)是否作为分隔符使用，等效于设定sep='\s+'。如果这个参数设定为Ture那么delimiter 参数失效。
# 在新版本0.18.1支持
#
# header : int or list of ints, default ‘infer’
# 指定行数用来作为列名，数据开始行数。如果文件中没有列名，则默认为0，否则设置为None。如果明确设定header=0 就会替换掉原来存在列名。header参数可以是一个list例如：[0,1,3]，这个list表示将文件中的这些行作为列标题（意味着每一列有多个标题），介于中间的行将被忽略掉（例如本例中的2；本例中的数据1,2,4行将被作为多级标题出现，第3行数据将被丢弃，dataframe的数据从第5行开始。）。
# 注意：如果skip_blank_lines=True 那么header参数忽略注释行和空行，所以header=0表示第一行数据而不是文件的第一行。
#
# names : array-like, default None
# 用于结果的列名列表，如果数据文件中没有列标题行，就需要执行header=None。默认列表中不能出现重复，除非设定参数mangle_dupe_cols=True。
#
# index_col : int or sequence or False, default None
# 用作行索引的列编号或者列名，如果给定一个序列则有多个行索引。
# 如果文件不规则，行尾有分隔符，则可以设定index_col=False 来是的pandas不适用第一列作为行索引。
#
# usecols : array-like, default None
# 返回一个数据子集，该列表中的值必须可以对应到文件中的位置（数字可以对应到指定的列）或者是字符传为文件中的列名。例如：usecols有效参数可能是 [0,1,2]或者是 [‘foo’, ‘bar’, ‘baz’]。使用这个参数可以加快加载速度并降低内存消耗。
#
# as_recarray : boolean, default False
# 不赞成使用：该参数会在未来版本移除。请使用pd.read_csv(...).to_records()替代。
# 返回一个Numpy的recarray来替代DataFrame。如果该参数设定为True。将会优先squeeze参数使用。并且行索引将不再可用，索引列也将被忽略。
#
# squeeze : boolean, default False
# 如果文件值包含一列，则返回一个Series
#
# prefix : str, default None
# 在没有列标题时，给列添加前缀。例如：添加‘X’ 成为 X0, X1, ...
#
# mangle_dupe_cols : boolean, default True
# 重复的列，将‘X’...’X’表示为‘X.0’...’X.N’。如果设定为false则会将所有重名列覆盖。
#
# dtype : Type name or dict of column -> type, default None
# 每列数据的数据类型。例如 {‘a’: np.float64, ‘b’: np.int32}
#
# engine : {‘c’, ‘python’}, optional
# Parser engine to use. The C engine is faster while the python engine is currently more feature-complete.
# 使用的分析引擎。可以选择C或者是python。C引擎快但是Python引擎功能更加完备。
#
# converters : dict, default None
# 列转换函数的字典。key可以是列名或者列的序号。
#
# true_values : list, default None
# Values to consider as True
#
# false_values : list, default None
# Values to consider as False
#
# skipinitialspace : boolean, default False
# 忽略分隔符后的空白（默认为False，即不忽略）.
#
# skiprows : list-like or integer, default None
# 需要忽略的行数（从文件开始处算起），或需要跳过的行号列表（从0开始）。
#
# skipfooter : int, default 0
# 从文件尾部开始忽略。 (c引擎不支持)
#
# skip_footer : int, default 0
# 不推荐使用：建议使用skipfooter ，功能一样。
#
# nrows : int, default None
# 需要读取的行数（从文件头开始算起）。
#
# na_values : scalar, str, list-like, or dict, default None
# 一组用于替换NA/NaN的值。如果传参，需要制定特定列的空值。默认为‘1.#IND’, ‘1.#QNAN’, ‘N/A’, ‘NA’, ‘NULL’, ‘NaN’, ‘nan’`.
#
# keep_default_na : bool, default True
# 如果指定na_values参数，并且keep_default_na=False，那么默认的NaN将被覆盖，否则添加。
#
# na_filter : boolean, default True
# 是否检查丢失值（空字符串或者是空值）。对于大文件来说数据集中没有空值，设定na_filter=False可以提升读取速度。
#
# verbose : boolean, default False
# 是否打印各种解析器的输出信息，例如：“非数值列中缺失值的数量”等。
#
# skip_blank_lines : boolean, default True
# 如果为True，则跳过空行；否则记为NaN。
#
# parse_dates : boolean or list of ints or names or list of lists or dict, default False

# %% [markdown]
# ### 对于有header的数据的一般读取

# %%
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0)
df.head()
# Out:
#          name producer tag_location name.1  total_fans  \
# 0  东方风云榜-揭榜时刻    动感101           上海    排行榜      100327
# 1       越夜越动听    动感101           上海     热线       40689
# 2       郭亮直通车   上海交通广播           上海     民生       38121
# 3        汽车世界   上海交通广播           上海     汽车       28795
# 4     101娱乐在线    动感101           上海     资讯       27876
#
#                                       program_slider
# 0  http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# 1  http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...
# 2  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...
# 3  http://img-ossimg.ajmide.com/c_up/588fb3fc762f...
# 4  http://img-ossimg.ajmide.com/c_up/3efdf9580010...

# %% [markdown]
# ### 对于读取数据的subset

# %%
df = pd.read_csv(
    '/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv'
    , header=0
    , usecols=['name','producer'])
df.head()
# Out:
#          name producer
# 0  东方风云榜-揭榜时刻    动感101
# 1       越夜越动听    动感101
# 2       郭亮直通车   上海交通广播
# 3        汽车世界   上海交通广播
# 4     101娱乐在线    动感101

# %% [markdown]
# ### set index

# %%
df = pd.read_csv(
    '/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv'
    , header=0
    , index_col='tag_location')
df.head()
# Out:
#                     name producer name.1  total_fans  \
# tag_location
# 上海            东方风云榜-揭榜时刻    动感101    排行榜      100327
# 上海                 越夜越动听    动感101     热线       40689
# 上海                 郭亮直通车   上海交通广播     民生       38121
# 上海                  汽车世界   上海交通广播     汽车       28795
# 上海               101娱乐在线    动感101     资讯       27876
#
#                                                  program_slider
# tag_location
# 上海            http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# 上海            http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...
# 上海            http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...
# 上海            http://img-ossimg.ajmide.com/c_up/588fb3fc762f...
# 上海            http://img-ossimg.ajmide.com/c_up/3efdf9580010...

# %% [markdown]
# ### 对header重命名

# %%
df = pd.read_csv(
    '/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv'
    ,sep=','
    ,skiprows=1
    ,names=['a','b','c','d','e','f']
)
df.head()
# Out:
#             a       b   c    d       e  \
# 0  东方风云榜-揭榜时刻   动感101  上海  排行榜  100327
# 1       越夜越动听   动感101  上海   热线   40689
# 2       郭亮直通车  上海交通广播  上海   民生   38121
# 3        汽车世界  上海交通广播  上海   汽车   28795
# 4     101娱乐在线   动感101  上海   资讯   27876
#
#                                                    f
# 0  http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# 1  http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...
# 2  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...
# 3  http://img-ossimg.ajmide.com/c_up/588fb3fc762f...
# 4  http://img-ossimg.ajmide.com/c_up/3efdf9580010...

# %%
df.columns = ['01','02','03','04','05','06']
df.head(20)
# Out:
#                 01            02  03   04      05  \
# 0       东方风云榜-揭榜时刻         动感101  上海  排行榜  100327
# 1            越夜越动听         动感101  上海   热线   40689
# 2            郭亮直通车        上海交通广播  上海   民生   38121
# 3             汽车世界        上海交通广播  上海   汽车   28795
# 4          101娱乐在线         动感101  上海   资讯   27876
# 5           101人来疯         动感101  上海   华语   26246
# 6          103怀旧金曲    Love Radio  上海   怀旧   26165
# 7            强强三人组        五星体育广播  上海   其他   19255
# 8   Love Radio特别专区    Love Radio  上海   其他   17528
# 9           午后原味音乐         动感101  上海   华语   16760
# 10           乐游三至五    Love Radio  上海   华语   16106
# 11           音乐零负担    Love Radio  上海   华语   14529
# 12             夜倾情        贵州交通广播  贵州   陪伴   13988
# 13          990早新闻        上海新闻广播  上海   综合   13727
# 14        东方之声精品剧场     东方之声精品工作室  上海   悬疑   12874
# 15           交易进行时        第一财经广播  上海   股市   12680
# 16          英语300句  北京人民广播电台教学广播  北京   英语   11882
# 17           音乐早早餐         动感101  上海   华语   11727
# ...

# %% [markdown]
# ### chunk size 使用

# %%
df_chunk = pd.read_csv(
    '/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv'
    ,chunksize = 1000
)

cnt=0
for chunk in df_chunk:
    cnt = cnt + 1
    print(chunk.head(5))
    if cnt >3:break
# Out:
#          name producer tag_location name.1  total_fans  \
# 0  东方风云榜-揭榜时刻    动感101           上海    排行榜      100327
# 1       越夜越动听    动感101           上海     热线       40689
# 2       郭亮直通车   上海交通广播           上海     民生       38121
# 3        汽车世界   上海交通广播           上海     汽车       28795
# 4     101娱乐在线    动感101           上海     资讯       27876
#
#                                       program_slider
# 0  http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# 1  http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...
# 2  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...
# 3  http://img-ossimg.ajmide.com/c_up/588fb3fc762f...
# 4  http://img-ossimg.ajmide.com/c_up/3efdf9580010...
#       name producer tag_location name.1  total_fans  \
# 1000   爱无言   江西音乐广播           江西     怀旧         187
# 1001    倾诉   山西文艺广播           山西     陪伴         187
# 1002   养生堂   苏州戏曲广播           江苏     其他         186
# 1003  原创贵州   贵州音乐广播           贵州     华语         186
# ...

# %%
reader = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', iterator=True)
 
loop = True
chunkSize = 1000
chunks = []
while loop:
    try:
        chunk = reader.get_chunk(chunkSize)
        chunks.append(chunk)
    except StopIteration:
        loop = False
        print("Iteration is stopped.")
df = pd.concat(chunks, ignore_index=True)

df.head()
# Out:
# Iteration is stopped.
#          name producer tag_location name.1  total_fans  \
# 0  东方风云榜-揭榜时刻    动感101           上海    排行榜      100327
# 1       越夜越动听    动感101           上海     热线       40689
# 2       郭亮直通车   上海交通广播           上海     民生       38121
# 3        汽车世界   上海交通广播           上海     汽车       28795
# 4     101娱乐在线    动感101           上海     资讯       27876
#
#                                       program_slider
# 0  http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# 1  http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...
# 2  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...
# 3  http://img-ossimg.ajmide.com/c_up/588fb3fc762f...
# 4  http://img-ossimg.ajmide.com/c_up/3efdf9580010...

# %% [markdown]
# # how to slice data

# %%
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0,index_col='tag_location')
df.columns
# Out:
# Index(['name', 'producer', 'name.1', 'total_fans', 'program_slider'], dtype='object')

# %% [markdown]
# ### 按列query

# %%
df[['name','producer']].head()
# Out:
#                     name producer
# tag_location
# 上海            东方风云榜-揭榜时刻    动感101
# 上海                 越夜越动听    动感101
# 上海                 郭亮直通车   上海交通广播
# 上海                  汽车世界   上海交通广播
# 上海               101娱乐在线    动感101

# %%
df[['name','producer']][1:3]
# Out:
#                name producer
# tag_location
# 上海            越夜越动听    动感101
# 上海            郭亮直通车   上海交通广播

# %% [markdown]
# ### 按行索引query

# %%
df.ix[['宁夏','上海']]
# Out:
#                        name  producer name.1  total_fans  \
# tag_location
# 宁夏                广播剧：刑警803    宁夏交通广播     综合         721
# 宁夏               老梁观世界老梁故事汇  银川交通音乐广播     其他         190
# 宁夏                    不吐葡萄皮  银川交通音乐广播     特色         123
# 宁夏                     帮帮帮帮  银川交通音乐广播     民生         111
# 宁夏                     回家路上  银川交通音乐广播     其他         103
# 宁夏                     刷刷刷刷  银川交通音乐广播     特色         101
# 宁夏                  银川style  银川交通音乐广播     美食          99
# 宁夏                  1006点唱机  银川交通音乐广播     其他          78
# 宁夏                     黑胶时代  银川交通音乐广播     怀旧          77
# 宁夏                     午夜传奇    宁夏都市广播     悬疑          75
# 宁夏                    中国相声榜    宁夏都市广播     相声          74
# 宁夏                    中国相声榜    宁夏都市广播     其他          70
# 宁夏                       夜歌    宁夏都市广播     华语          61
# 宁夏                     历史传奇  银川交通音乐广播     历史          59
# 宁夏                     峰人学院    宁夏都市广播     其他          58
# ...

# %% [markdown]
# ### mul conditional query

# %%
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0)

ninxia = df['tag_location'] == '宁夏'
total_fans_by_500 = df['total_fans'] > 100

sh = df['tag_location'] == '上海'
total_fans_by_1000 = df['total_fans'] > 1000
df[(ninxia&total_fans_by_500)|(sh&total_fans_by_1000)]
# Out:
#                 name    producer tag_location name.1  total_fans  \
# 0         东方风云榜-揭榜时刻       动感101           上海    排行榜      100327
# 1              越夜越动听       动感101           上海     热线       40689
# 2              郭亮直通车      上海交通广播           上海     民生       38121
# 3               汽车世界      上海交通广播           上海     汽车       28795
# 4            101娱乐在线       动感101           上海     资讯       27876
# 5             101人来疯       动感101           上海     华语       26246
# 6            103怀旧金曲  Love Radio           上海     怀旧       26165
# 7              强强三人组      五星体育广播           上海     其他       19255
# 8     Love Radio特别专区  Love Radio           上海     其他       17528
# 9             午后原味音乐       动感101           上海     华语       16760
# 10             乐游三至五  Love Radio           上海     华语       16106
# 11             音乐零负担  Love Radio           上海     华语       14529
# 13            990早新闻      上海新闻广播           上海     综合       13727
# ...

# %%
df_filtered = df[(df.tag_location == '上海') & (df.total_fans > 1000)]
df_filtered




df_filtered_2 = df[
    (df.tag_location.isin(['上海','宁夏'])) & (df.total_fans > 100)
     ].sort_values(['name.1','total_fans'], ascending=[True, False])
df_filtered_2
# Out:
#                 name    producer tag_location name.1  total_fans  \
# 165           上海，你早！      上海交通广播           上海     健康        2103
# 340             蔚兰晨曲      上海新闻广播           上海     健康         868
# 1119           运动与健康      五星体育广播           上海     健身         152
# 71              月光宝盒      上海故事广播           上海   儿童故事        4599
# 53              直通公司      第一财经广播           上海     公司        5913
# 7              强强三人组      五星体育广播           上海     其他       19255
# 8     Love Radio特别专区  Love Radio           上海     其他       17528
# 19        第一财经广播特别专区      第一财经广播           上海     其他       10816
# 22             体坛怡佳壹      五星体育广播           上海     其他        9954
# 30             有请发言人      上海交通广播           上海     其他        8185
# 48           对不起,我爱你       动感101           上海     其他        6127
# 49       899驾车调频特别专区     899驾车调频           上海     其他        6085
# 59           940激情赛场      五星体育广播           上海     其他        5117
# ...

# %% [markdown]
# ###  how to sort data

# %%
df.sort_values(['name.1','total_fans'], ascending=[True, False])
# Out:
#                name         producer tag_location name.1  total_fans  \
# 102            四季养生         山东人民广播电台           山东     健康        3275
# 110           大医生来了             浙江之声           浙江     健康        3113
# 146         998养生有道           成都新闻广播           四川     健康        2336
# 165          上海，你早！           上海交通广播           上海     健康        2103
# 198           健康新空气           河南新闻广播           河南     健康        1757
# 217            养生论坛             辽宁之声           辽宁     健康        1501
# 222          585养生堂           福建东南广播           福建     健康        1433
# 335           养生大讲堂          CNR中国之声           全国     健康         878
# 340            蔚兰晨曲           上海新闻广播           上海     健康         868
# 454          985养生馆           江西农村广播           江西     健康         572
# 457           健康快车道           湖北生活广播           湖北     健康         571
# 707        健康直通车上午版           江西民生广播           江西     健康         309
# 749        健康直通车下午版           江西民生广播           江西     健康         285
# ...

# %% [markdown]
# ### check data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15388 entries, 0 to 15387
# Data columns (total 6 columns):
# name              15388 non-null object
# producer          15388 non-null object
# tag_location      15375 non-null object
# name.1            15386 non-null object
# total_fans        15388 non-null int64
# program_slider    15388 non-null object
# dtypes: int64(1), object(5)
# memory usage: 721.4+ KB

# %%
df.dtypes
# Out:
# name              object
# producer          object
# tag_location      object
# name.1            object
# total_fans         int64
# program_slider    object
# dtype: object

# %%
df.describe(include = 'all')
# Out:
#          name producer tag_location name.1     total_fans  \
# count   15388    15388        15375  15386   15388.000000
# unique  11691      853           45     51            NaN
# top     爱车天天汇     网络电台           江苏     其他            NaN
# freq       39       66         1387   4553            NaN
# mean      NaN      NaN          NaN    NaN     117.839160
# std       NaN      NaN          NaN    NaN    1207.006143
# min       NaN      NaN          NaN    NaN       0.000000
# 25%       NaN      NaN          NaN    NaN       1.000000
# 50%       NaN      NaN          NaN    NaN       5.000000
# 75%       NaN      NaN          NaN    NaN      22.000000
# max       NaN      NaN          NaN    NaN  100327.000000
#
#                                            program_slider
# count                                               15388
# unique                                                 19
# top     http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# ...

# %%
df.describe(include = ['object'])
# Out:
#          name producer tag_location name.1  \
# count   15388    15388        15375  15386
# unique  11691      853           45     51
# top     爱车天天汇     网络电台           江苏     其他
# freq       39       66         1387   4553
#
#                                            program_slider
# count                                               15388
# unique                                                 19
# top     http://img-ossimg.ajmide.com/c_up/88ce89925ac7...
# freq                                                 4277

# %% [markdown]
# # create a new column

# %%
def func(row):
    if row['tag_location'] == '宁夏':
        return '宁夏', 'mgu'
    elif row['total_fans'] > 1000:
        return '>1000' 
    else:
        return row['total_fans'] +1

df['new_col'] = df.apply(func, axis=1)

df[df['total_fans']>100].head()
df[df['tag_location']=='宁夏'].head()
# Out:
#             name  producer tag_location name.1  total_fans  \
# 382    广播剧：刑警803    宁夏交通广播           宁夏     综合         721
# 987   老梁观世界老梁故事汇  银川交通音乐广播           宁夏     其他         190
# 1259       不吐葡萄皮  银川交通音乐广播           宁夏     特色         123
# 1330        帮帮帮帮  银川交通音乐广播           宁夏     民生         111
# 1398        回家路上  银川交通音乐广播           宁夏     其他         103
#
#                                          program_slider    new_col
# 382   http://img-ossimg.ajmide.com/c_up/d21e61d3f992...  (宁夏, mgu)
# 987   http://img-ossimg.ajmide.com/c_up/671a4dc86e5a...  (宁夏, mgu)
# 1259  http://img-ossimg.ajmide.com/c_up/df60c3d84a3a...  (宁夏, mgu)
# 1330  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...  (宁夏, mgu)
# 1398  http://img-ossimg.ajmide.com/c_up/300e9289df86...  (宁夏, mgu)

# %%
df['total_fans'].apply(lambda s: pd.Series({'feature1':s+1, 'feature2':s-1}))
# Out:
#        feature1  feature2
# 0        100328    100326
# 1         40690     40688
# 2         38122     38120
# 3         28796     28794
# 4         27877     27875
# 5         26247     26245
# 6         26166     26164
# 7         19256     19254
# 8         17529     17527
# 9         16761     16759
# 10        16107     16105
# 11        14530     14528
# 12        13989     13987
# 13        13728     13726
# 14        12875     12873
# 15        12681     12679
# 16        11883     11881
# 17        11728     11726
# 18        11139     11137
# 19        10817     10815
# 20        10637     10635
# 21        10067     10065
# 22         9955      9953
# 23         9833      9831
# 24         9621      9619
# 25         9317      9315
# 26         9200      9198
# 27         9168      9166
# 28         8909      8907
# 29         8636      8634
# ...         ...       ...
# 15358         1        -1
# 15359         1        -1
# 15360         1        -1
# ...

# %%
def calcu_1(row):
    return row['total_fans']+1
def calcu_2(row):
    return row['total_fans']-1

df['feature1'] = df.apply(calcu_1,  axis=1)
df['feature2'] = df.apply(calcu_2,  axis=1)
df
# Out:
#                  name          producer tag_location name.1  total_fans  \
# 0          东方风云榜-揭榜时刻             动感101           上海    排行榜      100327
# 1               越夜越动听             动感101           上海     热线       40689
# 2               郭亮直通车            上海交通广播           上海     民生       38121
# 3                汽车世界            上海交通广播           上海     汽车       28795
# 4             101娱乐在线             动感101           上海     资讯       27876
# 5              101人来疯             动感101           上海     华语       26246
# 6             103怀旧金曲        Love Radio           上海     怀旧       26165
# 7               强强三人组            五星体育广播           上海     其他       19255
# 8      Love Radio特别专区        Love Radio           上海     其他       17528
# 9              午后原味音乐             动感101           上海     华语       16760
# 10              乐游三至五        Love Radio           上海     华语       16106
# 11              音乐零负担        Love Radio           上海     华语       14529
# ...

# %% [markdown]
# # join

# %%
pd.merge(A_df, B_df,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])

# %% [markdown]
# # plot

# %%
import plotly.plotly as py  
from plotly.graph_objs import *  
  
import plotly   
plotly.tools.set_credentials_file(username='turbo_jy', api_key='IYMVN6WDqjeMmbIFtXgL')
trace0 = Scatter(  
    x=[1, 2, 3, 4],  
    y=[10, 15, 13, 17]  
)  
trace1 = Scatter(  
    x=[1, 2, 3, 4],  
    y=[16, 5, 11, 9]  
)  

data = Data([trace0, trace1])  
  
  
py.plot(data, filename = 'basic-line')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~turbo_jy/0 or inside your plot.ly account where it is named 'basic-line'
# 'https://plot.ly/~turbo_jy/0'

# %% [markdown]
# # aggregation

# %%
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0)
df.rename(
    columns={
        "name.1": "tag"
    },
    inplace=True
)
df.groupby('tag_location').total_fans.sum()
# Out:
# tag_location
# 三亚          7
# 上海     925746
# 中国       1428
# 云南       2895
# 保定         22
# 全国     168511
# 兵团        142
# 内蒙古      5749
# 北京      70898
# 南海        246
# 吉林       6810
# 吕梁         13
# 四川      15473
# 天津      17932
# 宁夏       3786
# 安徽       7647
# 宜宾         13
# 山东      25028
# 山西      10465
# 广东      34275
# 广西      51058
# 悉尼       3460
# 新疆       1495
# 江苏      71991
# 江西      30616
# 沈阳         18
# 沧州          2
# 河北      12679
# 河南      12666
# 浙江      25406
# 海南       1606
# 湖北     115599
# 湖南       3363
# 甘肃      10739
# 福建       7651
# 苏州          6
# 西藏        441
# 贵州      82439
# 辽宁      67571
# 辽宁省        59
# 邢台         11
# 重庆        693
# 陕西       4885
# 青海        987
# 黑龙江     10478
# Name: total_fans, dtype: int64

# %%
def create_col(row):
    return row['total_fans']+100
df['adj_total_fans'] = df.apply(create_col,  axis=1)
df[df.tag_location == '上海'].mean()
# Out:
# total_fans        2495.272237
# adj_total_fans    2595.272237
# dtype: float64

# %%
df2 = df.groupby(['tag_location','name']).agg({'total_fans':['count','sum'],'adj_total_fans':'sum' })
df2
# Out:
#                            total_fans        adj_total_fans
#                                 count    sum            sum
# tag_location name
# 三亚           1046帮你忙                1      0            100
#              三亚新闻                   1      1            101
#              中国音乐系列排行榜              1      0            100
#              人在旅途                   1      0            100
#              健康三亚                   1      0            100
#              夜读                     1      0            100
#              天涯书场                   1      0            100
#              天涯俱乐部                  1      0            100
#              天涯爱车汇                  1      0            100
#              家住海南                   1      0            100
#              小螺号                    1      2            102
#              我是大歌星                  1      0            100
#              政风行风热线                 1      0            100
# ...

# %%
df.head()
# Out:
#          name producer tag_location  tag  total_fans  \
# 0  东方风云榜-揭榜时刻    动感101           上海  排行榜      100327
# 1       越夜越动听    动感101           上海   热线       40689
# 2       郭亮直通车   上海交通广播           上海   民生       38121
# 3        汽车世界   上海交通广播           上海   汽车       28795
# 4     101娱乐在线    动感101           上海   资讯       27876
#
#                                       program_slider  adj_total_fans
# 0  http://img-ossimg.ajmide.com/c_up/88ce89925ac7...          100427
# 1  http://img-ossimg.ajmide.com/c_up/d9c2ab42e185...           40789
# 2  http://img-ossimg.ajmide.com/c_up/e12c63ceb8f6...           38221
# 3  http://img-ossimg.ajmide.com/c_up/588fb3fc762f...           28895
# 4  http://img-ossimg.ajmide.com/c_up/3efdf9580010...           27976

# %%
aggregations={
'total_fans':
    {#workonthe"duration"column
'total_duration':'sum',#get the sum,and call this result 'total_duration'
'average_duration':'mean',#get mean,call result'average_duration'
'cnt_duration':'count',
'max_duration':'max',
'test':lambda x:sum(x)
      },
'adj_total_fans':
    {#Nowworkonthe"date"column
'max_date':'max',#Findthemax,calltheresult"max_date"
'min_date':'min',
'first_date':'first',
'num_days':lambda x:max(x)-min(x)#Calculatethedaterangepergroup
  }
}
df1=df.groupby(['tag_location']).agg(aggregations)
df1
# Out:
#                  total_fans                                              \
#              total_duration average_duration cnt__duration max_duration
# tag_location
# 三亚                        7         0.269231            26            2
# 上海                   925746      2495.272237           371       100327
# 中国                     1428        39.666667            36          287
# 云南                     2895         7.347716           394          132
# 保定                       22         0.956522            23            5
# 全国                   168511       430.974425           391        10066
# 兵团                      142         9.466667            15           91
# 内蒙古                    5749         9.597663           599          160
# 北京                    70898       187.065963           379        11882
# 南海                      246        22.363636            11           76
# 吉林                     6810        19.682081           346          637
# ...

# %%
df1.columns
# Out:
# MultiIndex(levels=[['total_fans', 'adj_total_fans'], ['average_duration', 'cnt__duration', 'first_date', 'max_date', 'max_duration', 'min_date', 'num_days', 'test', 'total_duration']],
#            labels=[[0, 0, 0, 0, 0, 1, 1, 1, 1], [8, 0, 1, 4, 7, 3, 5, 2, 6]])

# %%
def fun1(x):
    f = x[(x['tag'] == '民生' )|( x['tag'] == '汽车')]['total_fans'].sum()
    g = x[(x['tag'] == '民生' )|( x['tag'] == '汽车')]['total_fans'].count()
    return [f,g]

df1 = df.groupby(['tag_location']).apply(fun1)
df1
# Out:
# tag_location
# 三亚          [0, 2]
# 上海      [67353, 7]
# 中国          [2, 1]
# 云南       [287, 28]
# 保定          [0, 0]
# 全国         [49, 3]
# 兵团          [0, 1]
# 内蒙古      [187, 34]
# 北京        [300, 6]
# 南海          [0, 0]
# 吉林        [99, 14]
# 吕梁          [0, 1]
# 四川       [916, 32]
# 天津         [69, 2]
# 宁夏        [220, 6]
# 安徽       [157, 27]
# 宜宾          [0, 1]
# 山东      [1723, 76]
# 山西       [459, 34]
# 广东      [1299, 54]
# 广西      [5630, 19]
# 悉尼          [0, 0]
# 新疆       [134, 18]
# 江苏      [4485, 81]
# 江西      [2438, 21]
# 沈阳          [0, 0]
# 沧州          [0, 0]
# 河北       [362, 42]
# 河南       [302, 47]
# 浙江      [1293, 81]
# 海南        [133, 8]
# 湖北     [13726, 32]
# 湖南        [90, 11]
# 甘肃      [1514, 16]
# 福建       [211, 20]
# 苏州          [1, 3]
# 西藏          [0, 0]
# 贵州      [2414, 19]
# 辽宁     [10792, 66]
# 辽宁省         [4, 1]
# 邢台          [0, 3]
# 重庆        [12, 10]
# 陕西       [377, 16]
# 青海         [24, 7]
# 黑龙江      [254, 20]
# dtype: object

# %%
def fun1(x):
    if (x['tag'] == '民生' )|( x['tag'] == '汽车')
        res_1 = x['total_fans'].sum()
    
    return res_1

df1 = df.groupby(['tag_location']).apply(fun1)
df1

# %% [markdown]
# ### rename

# %%
df.rename(
    columns={
        "name.1": "tag"
    },
    inplace=True
)
df

df.rename(columns=lambda x: x.lower().replace('_', ' '),inplace=True )

# %%
df
# Out:
#                  name          producer tag location    tag  total fans  \
# 0          东方风云榜-揭榜时刻             动感101           上海    排行榜      100327
# 1               越夜越动听             动感101           上海     热线       40689
# 2               郭亮直通车            上海交通广播           上海     民生       38121
# 3                汽车世界            上海交通广播           上海     汽车       28795
# 4             101娱乐在线             动感101           上海     资讯       27876
# 5              101人来疯             动感101           上海     华语       26246
# 6             103怀旧金曲        Love Radio           上海     怀旧       26165
# 7               强强三人组            五星体育广播           上海     其他       19255
# 8      Love Radio特别专区        Love Radio           上海     其他       17528
# 9              午后原味音乐             动感101           上海     华语       16760
# 10              乐游三至五        Love Radio           上海     华语       16106
# 11              音乐零负担        Love Radio           上海     华语       14529
# ...

# %% [markdown]
# ### drop colomns and rows

# %%
#drop rows
#df = df.drop([0,1,2], axis=0)
#df

#drop columns
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0)
df = df.drop(['total_fans','producer'], axis =1 )
df
# Out:
#                  name tag_location name.1  \
# 0          东方风云榜-揭榜时刻           上海    排行榜
# 1               越夜越动听           上海     热线
# 2               郭亮直通车           上海     民生
# 3                汽车世界           上海     汽车
# 4             101娱乐在线           上海     资讯
# 5              101人来疯           上海     华语
# 6             103怀旧金曲           上海     怀旧
# 7               强强三人组           上海     其他
# 8      Love Radio特别专区           上海     其他
# 9              午后原味音乐           上海     华语
# 10              乐游三至五           上海     华语
# 11              音乐零负担           上海     华语
# 12                夜倾情           贵州     陪伴
# 13             990早新闻           上海     综合
# 14           东方之声精品剧场           上海     悬疑
# 15              交易进行时           上海     股市
# 16             英语300句           北京     英语
# 17              音乐早早餐           上海     华语
# 18              康定小情歌           上海     怀旧
# 19         第一财经广播特别专区           上海     其他
# 20             爱在1072           上海     陪伴
# ...

# %% [markdown]
# ###  change type

# %%
df = pd.read_csv('/Users/admin/PycharmProjects/ad_hoc/pandas study/sample.csv', header = 0,dtype={'total_fans':float})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15388 entries, 0 to 15387
# Data columns (total 6 columns):
# name              15388 non-null object
# producer          15388 non-null object
# tag_location      15375 non-null object
# name.1            15386 non-null object
# total_fans        15388 non-null float64
# program_slider    15388 non-null object
# dtypes: float64(1), object(5)
# memory usage: 721.4+ KB

# %%
df['tag_location'] = df.tag_location.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15388 entries, 0 to 15387
# Data columns (total 6 columns):
# name              15388 non-null object
# producer          15388 non-null object
# tag_location      15375 non-null category
# name.1            15386 non-null object
# total_fans        15388 non-null float64
# program_slider    15388 non-null object
# dtypes: category(1), float64(1), object(4)
# memory usage: 616.6+ KB

# %% [markdown]
# #  SQL

# %%
import pandas as pd
import numpy as np
from pandasql import sqldf
from sklearn.datasets import load_iris
import re

iris = load_iris()

columns=[re.sub("[() ]", "", col) for col in iris.feature_names]
iris_df = pd.DataFrame(iris.data, columns=columns)
iris_df.head()
# Out:
#    sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
q = """
     select
       key1,
       sum(case when petalwidthcm =0.2 then sepalwidthcm end ) as v1,
       sum(case when petalwidthcm != 0.2 then sepalwidthcm end ) as v2,
       sum(sepalwidthcm) as v3,
       count(distinct sepalwidthcm) as v4
     from
     (
     select
        case 
          when sepallengthcm >= 5 then '>=5'
          else '<5'
        end as key1,
        *
      from
        iris_df
        )a
        group by 
        key1
    """

new_df = sqldf(q)


cnt = 0
for i in range(0,4):
    if cnt == 0:
        out_bf = new_df
    else:
        out_bf = pd.concat([out_bf,new_df])
    cnt = cnt + 1
out_bf
# Out:
#   key1    v1     v2     v3  v4
# 0   <5  38.3   28.9   67.2   9
# 1  >=5  56.6  334.3  390.9  23
# 0   <5  38.3   28.9   67.2   9
# 1  >=5  56.6  334.3  390.9  23
# 0   <5  38.3   28.9   67.2   9
# 1  >=5  56.6  334.3  390.9  23
# 0   <5  38.3   28.9   67.2   9
# 1  >=5  56.6  334.3  390.9  23

# %% [markdown]
# ## Creating bins

# %%
bins = [0, 1, 2, 3,9999999]
names = ['Cheap', 'Normal', 'Expensive','b']

iris_df['price_point'] = pd.cut(iris_df.sepalwidthcm, bins, labels=names)

iris_df.head()
# Out:
#    sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm price_point
# 0            5.1           3.5            1.4           0.2           b
# 1            4.9           3.0            1.4           0.2   Expensive
# 2            4.7           3.2            1.3           0.2           b
# 3            4.6           3.1            1.5           0.2           b
# 4            5.0           3.6            1.4           0.2           b

# %% [markdown]
# ##  multiindex
#          comprehensive_indicator
#    key       mean     sum
# 1    a        20
# 2    b
# 3    c

# %%
df_avg[('comprehensive_indicator', 'mean')].head()
df_avg.sort_values([('comprehensive_indicator','mean')], ascending=[False]).head(n=100)

# %%
import mysql.connector
import pandas as pd
def define_cnx(mysql_mode, database):

    cnx=''

    if mysql_mode == "analyze":
        cnx = mysql.connector.connect(user='jinyao', database=database,
                                      host='rdsua5i7pkip9jx53dwgb.mysql.rds.aliyuncs.com', password='jy1008', port=3306)

    if mysql_mode == "ods":
        cnx = mysql.connector.connect(user='jinyao', database=database,
                                  host='120.27.152.31', password='UKB04ngF',
                                  port=8306)
    if mysql_mode == "main":
        cnx = mysql.connector.connect(user='ajmide_stat_read', database=database,
                                      host='rds30s9go4s854r689d8.mysql.rds.aliyuncs.com', password='vnhf762Hfg3',
                                      port=3306)
    return cnx


sql="""
        SELECT
          *
        FROM
          audio_stat_daily
        where 
          date_ts >='2017-12-01' and date_ts <'2018-01-01'
       """

cnx = define_cnx("ods", "ajmide_dw")
df = pd.read_sql(sql,cnx)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d9ce0da6c053> in <module>()
#      30
#      31 cnx = define_cnx("ods", "ajmide_dw")
# ---> 32 df = pd.read_sql(sql,cnx)
#      33 df.head()
#
# /Users/admin/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# /Users/admin/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1443                                         parse_dates=parse_dates)
#    1444         else:
# -> 1445             data = self._fetchall_as_list(cursor)
# ...

# %% [markdown]
# ## 设置显示的列和行目数

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## 使用pivot对dataframe进行转置

# %%
df_new_t = df_new.pivot(index='product_code', columns='inv_date', values='main_prod_xssl')

# %% [markdown]
# # concat

# %%
for i in range(0,3):
    if i == 0:
        total = tmp
    else:
        total = pd.concat([total,tmp])
total
